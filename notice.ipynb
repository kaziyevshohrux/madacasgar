# %% [markdown]
# Fronted Development :
#   1) BSSR->backend service side rendering (DTE-> djngo templete engine /EJS)  -  frontedni backda qurish
#   2) SPA -> single page aplication(REACTjs/ AngularJS/Vuels)                  - faqat jesn malumot yubrdi

# %% [markdown]
# API design :
#   1) TRADITIONAL API  -> bssr
#   2) REST API         -> SPA
#   3) GRAPHQL API

# %% [markdown]
# Pettern :
#   1) design pattern -> middleWare , Decratr , observer
#   2) architectur pattern ->  MVC - model view controller , dependency injection , CQRS
#
#      MVS     client - >  url  -> controller - > model +> database +> model -> controller -<> view (html) -> controller - > url -> client
